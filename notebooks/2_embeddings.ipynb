# %% [markdown]
# # 2 - Embeddings
#
# ## 2.1 Local SentenceTransformers
#
# SentenceTransformers is a Python framework for state-of-the-art sentence, text, and image embeddings. It allows you to compute dense vector representations for sentences, paragraphs, and images that can be used for various tasks such as semantic search, clustering, and classification.
#
# More info at: https://sbert.net

# %%
# %pip install sentence-transformers
from sentence_transformers import SentenceTransformer, util

# 1. Load a pretrained Sentence Transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# The sentences to encode
sentences = ['Gestion des stocks', 'Prévision de la demande', 'Transport multimodal']

# 2. Calculate embeddings by calling model.encode()
emb = model.encode(sentences, convert_to_tensor=True)

# 3. Print the embeddings and their similarity
print('Embeddings shape:', emb.shape)

print(f"Similarité [{sentences[0]}]-[{sentences[1]}] :", util.pytorch_cos_sim(emb[0], emb[1]).item())

# pairwise cosine similarities
cosine_scores = util.pytorch_cos_sim(emb, emb)
print('Matrice de similarité:\n', cosine_scores)
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (5.2.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\x1gen4\downloads\gi-5-s1-ec-dsc_rag\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Embeddings shape: torch.Size([3, 384])
# Similarité [Gestion des stocks]-[Prévision de la demande] : 0.36206135153770447
# Matrice de similarité:
#  tensor([[1.0000, 0.3621, 0.0111],
#         [0.3621, 1.0000, 0.1350],
#         [0.0111, 0.1350, 1.0000]])

# %% [markdown]
# ## 2.2 - Embeddings endpoint with LMStudio
#
# LMStudio provides an API to generate embeddings using various models. Below is an example of how to create a custom embedding model class that interacts with the LMStudio API to fetch embeddings.
#
# You can install LMStudio on your computer by following the instructions at: https://lmstudio.ai

# %%
import requests
import numpy as np

api_url="http://localhost:1234/v1/embeddings"

class LMSEmbeddingModel:
    """
    Un remplaçant léger de SentenceTransformer utilisant un serveur LM Studio.
    Compatible : model.encode(texts)
    """

    def __init__(self, model_name, api_url=api_url):
        self.model_name = model_name
        self.api_url = api_url

    def encode(self, texts, convert_to_tensor=False):
        """
        Encode une liste de textes en embeddings.
        - texts : str ou List[str]
        - convert_to_tensor : ignoré, mais ajouté pour compatibilité
        """

        # Si un seul texte → transformer en liste
        if isinstance(texts, str):
            texts = [texts]

        payload = {
            "model": self.model_name,
            "input": texts
        }

        response = requests.post(self.api_url, json=payload)
        response.raise_for_status()
        data = response.json()

        embeddings = [item["embedding"] for item in data["data"]]
        embeddings = np.array(embeddings)

        return embeddings

# %%
from sentence_transformers import util

# 1. Load an embedding model from LM Studio
api_url="http://localhost:1234/v1/embeddings"
model = LMSEmbeddingModel("text-embedding-sentence-transformers_all-minilm-l12-v2", api_url=api_url)

sentences = ["Gestion des stocks", "Prévision de la demande", "Transport multimodal"]

# 2. Calculate embeddings by calling model.encode()
emb = model.encode(sentences, convert_to_tensor=True)

# 3. Print the embeddings and their similarity
print("Shape :", emb.shape)

print(f"Similarité [{sentences[0]}]-[{sentences[1]}] :", util.pytorch_cos_sim(emb[0], emb[1]).item())

cosine_scores = util.pytorch_cos_sim(emb, emb)
print("Matrice de similarité :\n", cosine_scores)
# Out:
# Shape : (3, 384)
# Similarité [Gestion des stocks]-[Prévision de la demande] : 0.2928846007211735
# Matrice de similarité :
#  tensor([[ 1.0000,  0.2929, -0.0111],
#         [ 0.2929,  1.0000,  0.0086],
#         [-0.0111,  0.0086,  1.0000]], dtype=torch.float64)
