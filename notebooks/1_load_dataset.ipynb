# %% [markdown]
# # 1 - Load HuggingFace datasets
#
# Example of loading datasets from the HuggingFace Hub using the `datasets` library.

# %%
from datasets import load_dataset

dataset = load_dataset("parclytaxel/SMRT-Maintenance-Logs")

df = dataset["train"].to_pandas()
df
# Out:
#                                                    text  label
# 0     TIMS showed intermittent BCU brake faultat car...      3
# 1     TC reported TIMS showed air dryer faultat car ...     21
# 2     Snaprep: 3540 One saloon light blown ~~~~~ Sna...      0
# 3     1547 CE reported No.2 end gangway A/s ce ~~~~~...    139
# 4     3554 DT check found bogie 2 having heavy ~~~~~...     44
# ...                                                 ...    ...
# 9701  Pax feedback water leakage to staff (TIB). Sta...     17
# 9702  ECB activated at front M2 car due to smoke fro...     10
# 9703  PM checked found the following CCD assembly wa...     22
# 9704  TC T207 feedback counter bound T414 LHShead li...      9
# 9705  Snap: 1643 Aircon condensation ~~~~~ Snap: 164...     17
#
# [9706 rows x 2 columns]
